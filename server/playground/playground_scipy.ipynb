# %%
from scipy import integrate

# Calculer l'intégrale de la fonction f(x) = x^2 entre 0 et 1
result, error = integrate.quad(lambda x: x**2, 0, 1)
print(result)  # Donne 1/3
# Out:
# 0.33333333333333337

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

# Points de données discrets
x = np.linspace(0, 10, 20)
y = np.sin(x)

# Créer une fonction d'interpolation
f = interpolate.interp1d(x, y)

# Générer des points pour interpolation
x_new = np.linspace(0, 10, 100)  # Points plus fins pour l'interpolation
y_new = f(x_new)

# Tracer les points d'origine et la courbe interpolée
plt.plot(x, y, 'o', label='Points discrets')  # Points originaux
plt.plot(x_new, y_new, '-', label='Interpolation linéaire')  # Courbe interpolée

# Mettre en évidence la valeur interpolée pour x = 5.5
plt.scatter(5.5, f(5.5), color='red', zorder=5,
            label=f'Interpolation à x=5.5 : {f(5.5):.3f}')

plt.title('Interpolation linéaire des points')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

# Définir les matrices A et b
A = np.array([[3, 2], [1, 4]])
b = np.array([5, 6])

# Résoudre Ax = b
x = linalg.solve(A, b)
print("Solution de x:", x)

# Fonction pour afficher une matrice sous forme de heatmap
def plot_matrix(matrix, title):
    plt.imshow(matrix, cmap='viridis', interpolation='none')
    plt.colorbar()
    plt.title(title)
    plt.show()


# Représenter la matrice A, b et la solution x
plot_matrix(A, "Matrice A")
# Redimensionner b pour qu'il soit affiché comme une colonne
plot_matrix(b.reshape(-1, 1), "Vecteur b")
# Afficher la solution x comme une colonne
plot_matrix(x.reshape(-1, 1), "Solution x")
# Out:
# Solution de x: [0.8 1.3]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# Définir la fonction quadratique


def f(x):
    return (x - 3) ** 2


# Trouver le minimum
result = minimize(f, 0)

# Tracer la fonction
x_values = np.linspace(-1, 7, 400)  # Générer des valeurs de x de -1 à 7
y_values = f(x_values)  # Calculer les valeurs correspondantes de f(x)

plt.plot(x_values, y_values, label='f(x) = (x-3)^2')
plt.scatter(result.x, f(result.x), color='red', zorder=5,
            label='Minimum')  # Marquer le minimum
plt.title('Fonction quadratique et son minimum')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
